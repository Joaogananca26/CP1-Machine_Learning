# %% [markdown]
# ### Exercício 36
#
#  #### 9 variáveis e 2075259 registros

# %% [markdown]
# ### Exercício 37
#
# Com base no histograma, podemos concluir que sim![distribuitons-global-active.png](data:image/png;base64,...)

# %% [markdown]
# ### Exercício 38
# Pelo histograma, é possível observar que cerca de 56% dos valores de Global_active_power estão abaixo de 1 kW (46,5% entre 0 e 0,5 kW e 10% entre 0,5 e 1 kW). À medida que o consumo aumenta, a frequência dos registros diminui rapidamente, indicando que o consumo é predominantemente baixo, com poucos casos de maior consumo.

# %% [markdown]
# ### Exercício 39
# ![scatter.png](data:image/png;base64,...)
# Pelo scatter plot, observa-se que a maioria dos dados está concentrada entre 230 e 250 V, com valores de Global_intensity abaixo de 20 A. Não há um padrão claro que indique correlação forte entre as variáveis, sugerindo que a relação entre elas é fraca ou inexistente.

# %% [markdown]
# ### Exercício 40
#
# ![Captura de tela 2025-08-28 scatterplot.png](data:image/png;base64,...)

# %% [markdown]
# Para esta análise utilizamos o PCA, reduzindo as 3 variáveis de Sub_metering para 2 componentes principais, de forma a possibilitar a visualização em um scatter plot (eixo X e Y).
# Observa-se que os 3 clusters formados representam diferentes tipos de consumo doméstico:
#
# O cluster vermelho apresenta os menores valores nos dois componentes principais, indicando consumo muito baixo em todos os Sub_metering.
#
# O cluster azul, localizado entre o vermelho e o verde, sugere um nível de consumo moderado.
#
# O cluster verde, acima dos demais, representa registros com consumo mais elevado em pelo menos um dos Sub_metering.
